# %% [markdown]
# <a href="https://colab.research.google.com/github/shaviratan/laravelskill/blob/main/Selamat_Datang_di_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Declaring Variable in Python

# %% [markdown]
# ##1.1 Subbab

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %%
stringy = "Hello world"
stringy.replace('o', 'q')
fruitBasket = ["apple", "manggo", "straw"]
#replace
fruitBasket[fruitBasket.index("manggo")] = "water"

# %% [markdown]
# # 2. &nbsp; Hello World

# %%
fruitBasket = [
    'banana',
    'mango',
    'guava',
    'orange',
    'strawberry',
    'semangka',
    'melon',
    'apple',
    'manggo'
]

for idx, fruit in enumerate(fruitBasket):
  print(idx, fruit)
  if fruit == "mango"
# Out:
# 0 banana
# 1 mango
# 2 guava
# 3 orange
# 4 strawberry
# 5 mango
# 6 melon
# 7 apple
# 8 manggo

# %% [markdown]
# ## 2.2 &nsbp Subbab

# %%
myDict = {
    "Nama" : "Hendy",
    "Tinggi Badan" : 165.34,
    "Berat Badan" : 73.54,
    "Kelas" : 3,
    "Lulus" : True,
    "Nilai Ujian" : {"Fisika": 90, "Matematika":85}
}
for key, val in myDict.items():
  print(key, val)
# Out:
# Nama Hendy
# Tinggi Badan 165.34
# Berat Badan 73.54
# Kelas 3
# Lulus True
# Nilai Ujian {'Fisika': 90, 'Matematika': 85}

# %% [markdown]
# # Looping

# %%
batas = 10
start = 0

while True:
    if start > batas:
        break

    if start % 3 == 0:
        print(start, "→ Hello World")
    else:
        print(start, "→ Hello Programming")

    start += 1
# Out:
# 0 → Hello World
# 1 → Hello Programming
# 2 → Hello Programming
# 3 → Hello World
# 4 → Hello Programming
# 5 → Hello Programming
# 6 → Hello World
# 7 → Hello Programming
# 8 → Hello Programming
# 9 → Hello World
# 10 → Hello Programming

# %% [markdown]
# Anda dapat mengimpor data sendiri ke notebook Colab dari akun Google Drive Anda, termasuk dari spreadsheet, GitHub, dan berbagai sumber lainnya. Untuk mempelajari lebih lanjut pengimporan data dan bagaimana Colab dapat digunakan untuk ilmu data, lihat link di bawah pada bagian <a href="#working-with-data">Bekerja dengan Data</a>.

# %%
print("Hello, World")
# Out:
# Hello, World

# %%
import numpy as np
import IPython.display as display
from matplotlib import pyplot as plt
import io
import base64

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

fig = plt.figure(figsize=(4, 3), facecolor='w')
plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)
plt.title("Sample Visualization", fontsize=10)

data = io.BytesIO()
plt.savefig(data)
image = F"data:image/png;base64,{base64.b64encode(data.getvalue()).decode()}"
alt = "Sample Visualization"
display.display(display.Markdown(F"""![{alt}]({image})"""))
plt.close(fig)
# Out:
# ![Sample Visualization](data:image/png;base64,...)

# %% [markdown]
# Notebook Colab mengeksekusi kode di server cloud Google. Artinya, Anda dapat memanfaatkan kecanggihan hardware Google, termasuk <a href="#using-accelerated-hardware">GPU dan TPU</a>, terlepas dari kecanggihan komputer Anda. Yang Anda butuhkan hanyalah browser.
#
# Misalnya, jika Anda harus menunggu kode <strong>pandas</strong> selesai dijalankan dan ingin mempercepat prosesnya, Anda dapat beralih ke Runtime GPU dan menggunakan library seperti <a href="https://rapids.ai/cudf-pandas">RAPIDS cuDF</a> yang menyediakan akselerasi tanpa perubahan kode.

# %% [markdown]
# Untuk mempelajari lebih lanjut cara mempercepat pandas di Colab, lihat <a href="https://colab.research.google.com/github/rapidsai-community/showcase/blob/main/getting_started_tutorials/cudf_pandas_colab_demo.ipynb">panduan 10 menit</a> atau
#  <a href="https://colab.research.google.com/github/rapidsai-community/showcase/blob/main/getting_started_tutorials/cudf_pandas_stocks_demo.ipynb">demo analisis data pasar saham AS</a>.
